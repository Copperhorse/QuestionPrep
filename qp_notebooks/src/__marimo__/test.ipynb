# %%
import marimo as mo

# %%
import sqlalchemy

DATABASE_URL = (
    "sqlite:////home/copper/Desktop/Project/QuestionPrep/data/rag_staging.db"
)
engine = sqlalchemy.create_engine(DATABASE_URL)

# %%
_df = mo.sql(
    f"""
    Select * FROm files
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='vblA-0' random-id='595f06ac-2281-3899-d4c9-1b1e2080a0ab'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;file_id&#92;&quot;:&#92;&quot;c2323cdd-0cd4-4560-87ea-e496d00a0f0a&#92;&quot;,&#92;&quot;file_path&#92;&quot;:&#92;&quot;1811.03402v2.pdf&#92;&quot;,&#92;&quot;file_name&#92;&quot;:&#92;&quot;1811.03402v2.pdf&#92;&quot;,&#92;&quot;simhash&#92;&quot;:&#92;&quot;6fc90de255c6d717&#92;&quot;,&#92;&quot;format&#92;&quot;:&#92;&quot;PDF 1.5&#92;&quot;,&#92;&quot;title&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;author&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;creation_date&#92;&quot;:&#92;&quot;D:20190813003526Z&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-03-23T07:51:58.967699&#92;&quot;,&#92;&quot;content_length&#92;&quot;:122903}]&quot;' data-total-rows='1' data-total-columns='10' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;file_id&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;file_path&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;file_name&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;simhash&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;format&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;title&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;author&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;creation_date&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;processed_at&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;content_length&quot;,[&quot;integer&quot;,&quot;i64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
_df = mo.sql(
    f"""
    SELECT
        *
    FROM
        chunks
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='bkHC-0' random-id='3f65dc49-5d00-3ad0-b3a6-f2721bc92130'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;dd214c8a-fd02-48ed-be90-3ee237a296d9&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;c2323cdd-0cd4-4560-87ea-e496d00a0f0a&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:0,&#92;&quot;content&#92;&quot;:&#92;&quot;A Big Data - AI Integration Perspective&#92;&#92;n&#92;&#92;nYuji Roh, Geon Heo, Steven Euijong Whang, Senior Member, IEEE&#92;&#92;n&#92;&#92;nAbstract -Data collection is a major bottleneck in machine learning and an active research topic in multiple communities. There are largely two reasons data collection has recently become a critical issue. First, as machine learning is becoming more widely-used, we are seeing new applications that do not necessarily have enough labeled data. Second, unlike traditional machine learning, deep learning techniques automatically generate features, which saves feature engineering costs, but in return may require larger amounts of labeled data. Interestingly, recent research in data collection comes not only from the machine learning, natural language, and computer vision communities, but also from the data management community due to the importance of handling large amounts of data. In this survey, we perform a comprehensive study of data collection from a data management point of view. Data collection largely consists of data acquisition, data labeling, and improvement of existing data or models. We provide a research landscape of these operations, provide guidelines on which technique to use when, and identify interesting research challenges. The integration of machine learning and data management for data collection is part of a larger trend of Big data and Artificial Intelligence (AI) integration and opens many opportunities for new research.&#92;&#92;n&#92;&#92;nIndex Terms -data collection, data acquisition, data labeling, machine learning&#92;&#92;n&#92;&#92;nF&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:387,&#92;&quot;section_header&#92;&quot;:&#92;&quot;A Survey on Data Collection for Machine Learning&#92;&quot;,&#92;&quot;parent_section&#92;&quot;:null,&#92;&quot;top_header&#92;&quot;:&#92;&quot;A Survey on Data Collection for Machine Learning&#92;&quot;,&#92;&quot;prev_chunk_id&#92;&quot;:null,&#92;&quot;next_chunk_id&#92;&quot;:&#92;&quot;4d40252e-8e5f-484b-9996-863267abfbb2&#92;&quot;,&#92;&quot;quality_score&#92;&quot;:80.0,&#92;&quot;should_use&#92;&quot;:1},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;4d40252e-8e5f-484b-9996-863267abfbb2&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;c2323cdd-0cd4-4560-87ea-e496d00a0f0a&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:1,&#92;&quot;content&#92;&quot;:&#92;&quot;W Eareliving in exciting times where machine learning is having a profound influence on a wide range of applications from text understanding, image and speech recognition, to health care and genomics. As a striking example, deep learning techniques are known to perform on par with ophthalmologists on identifying diabetic eye diseases in images [1]. Much of the recent success is due to better computation infrastructure and large amounts of training data.&#92;&#92;n&#92;&#92;nAmong the many challenges in machine learning, data collection is becoming one of the critical bottlenecks. It is known that the majority of the time for running machine learning end-to-end is spent on preparing the data, which includes collecting, cleaning, analyzing, visualizing, and feature engineering. While all of these steps are timeconsuming, data collection has recently become a challenge due to the following reasons.&#92;&#92;n&#92;&#92;nFirst, as machine learning is used in new applications, it is usually the case that there is not enough training data. Traditional applications like machine translation or object d ...

# %%
_df = mo.sql(
    f"""
    SELECT
        *
    FROM
        chunk_enrichments
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='lEQa-0' random-id='d984a6cc-c70c-0536-7308-f24046049425'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;dd214c8a-fd02-48ed-be90-3ee237a296d9&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;data_collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data_acquisition&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;involves&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data acquisition&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;includes&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data labeling&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data management&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;adds&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;}]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The text discusses data collection challenges in machine learning and its integration with data management.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-03-23T07:54:43.359118&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;data_discovery&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data_augmentation&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data acquisition&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;involves&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;techniques&#92;&#92;&#92;&quot;}]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The text outlines three data acquisition approaches for machine learning. It mentions data discovery, data augmentation, and data generation. Specific methods and operations are detailed in the sections.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-03-23T21:02:49.421460&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;52771d1d-9b5c-4d6b-9553-347f2c9ef82b&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;data_discovery&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The text explains data discovery as a two-step process involving indexing and sharing. It mentions collaborative systems and post-hoc metadata generation. The key methods include data discovery, data augmentation, and data generation.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-03-23T21:09:25.933247&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;accfae02-e844-437a-84a3-4d47e28d2048&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The text describes data acquisition methods including discovery, augmentation, and generation. It outlines systems like DataHub and Fusion Tables for sharing and analysis. Kaggle integrates competitions with datasets for machine learning use.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-03-23T21:13:00.226616&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;d54d3809-d8be-4498-bbbf-5694b34ddf2a&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;& ...

# %%
_df = mo.sql(
    f"""
    SELECT * 
    FROM chunk_questions 
    WHERE question_text LIKE '%space complexity of EXPANDER%O(1) per node%'
       OR question_text LIKE '%data collection relate to the challenges in machine learning applications%';
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='PKri-0' random-id='059876d1-1a0d-966e-763b-6e42e324d0ad'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[]&quot;' data-total-rows='0' data-total-columns='0' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
_df = mo.sql(
    f"""
    SELECT 
        q.question_text, 
        q.answer_text, 
        q.source_quote,
        c.content,
        c.chunk_id,
        e.summary,
        c.file_id
    FROM chunk_questions q
    JOIN chunks c 
        ON q.chunk_id = c.chunk_id
    JOIN chunk_enrichments e 
        ON e.chunk_id = c.chunk_id
    WHERE c.should_use = 1 
    ORDER by e.processed_at DESC
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='SFPL-0' random-id='dcd46b25-049a-0132-c5ad-7723f26a4970'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;question_text&#92;&quot;:&#92;&quot;What are the two reasons X is a bottleneck?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The process of semi-supervised learning relies on balancing labeled and unlabeled data to improve model performance, and the text highlights that certain techniques can overlap in application. This overlap can create challenges when trying to optimize efficiency or accuracy across different scenarios.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;For semi-supervised learning techniques for classification, the goal is to train a model that returns one of multiple possible classes for each example using labeled and unlabeled datasets.&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;For semi-supervised learning techniques for classification, the goal is to train a model that returns one of multiple possible classes for each example using labeled and unlabeled datasets. We consider the best-performing techniques in a survey that focuses on labeling data [96], which are summarized in Figure 4. The performance results are similar regardless of using transductive or inductive learning.&#92;&#92;n&#92;&#92;nThe simplest class of semi-supervised learning techniques train one model using one learning algorithm on one set of features. For example, Self-training [92] initially trains a model on the labeled examples. The model is then applied to all the unlabeled data where the examples are ranked by the confidences in their predictions. The most confident predictions are then added into the labeled examples. This process repeats until all the unlabeled examples are labeled.&#92;&#92;n&#92;&#92;nThe next class trains multiple classifiers by sampling the training data several times and training a model for each sample. For example, Tri-training [93] initially trains three models on the labeled examples using Bagging for the ensemble learning algorithm. Then each model is updated&#92;&#92;n&#92;&#92;nTABLE 2: A classification of data labeling techniques. Some of the techniques can be used for the same application. For example, for classification on graph data, both self-labeled techniques and label propagation can be used.&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;87e5536f-bca0-401f-8376-688357062a71&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The text explains data augmentation methods using embeddings and semantic linkage graphs for machine learning.&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;c2323cdd-0cd4-4560-87ea-e496d00a0f0a&#92;&quot;},{&#92;&quot;question_text&#92;&quot;:&#92;&quot;What are the two reasons X is a bottleneck?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The two reasons X is a bottleneck relate to the scarcity of labeled data and the need for effective ways to generate more labels using one&#x27;s own predictions. The text highlights that labeled data is costly and limited, while unlabeled data is abundant, making it essential to leverage self-labeled techniques to bridge that gap.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;semi-supervised learning is a broad topic, and we focus on a smaller branch of research called self-labeled techniques [96] where the goal is to generate more labels by trusting one&#x27;s own predictions.&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;A common setting in machine learning is to have a small amount of labeled data, which is expensive to produce with humans, along with a much larger amount of unlabeled data. Semi-supervised learning techniques [143] exploit both labeled and unlabeled data to make predictions. In a transductive learning setting, the entire unlabeled data is available while in an inductive learning setting, some unlabeled data is available, but the predictions must be on unseen data. Semi-superv ...

# %%
_df = mo.sql(
    f"""
    SELECT * FROM chunk_rejections
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='BYtC-0' random-id='f96f6e3c-d31f-5796-4032-edcdbd2a7675'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;dd214c8a-fd02-48ed-be90-3ee237a296d9_rej1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;dd214c8a-fd02-48ed-be90-3ee237a296d9&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What operations are involved in data collection from a data management perspective?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Quote/answer mismatch (12% overlap)&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-03-23T07:58:39.834613&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;From the passage, it&#92;&#92;u2019s clear that data collection from a data management standpoint involves several key activities. First, it includes gathering raw data, which is followed by labeling that data to make it usable for machine learning models. Then there&#92;&#92;u2019s the ongoing effort to enhance existing data or models, ensuring they remain accurate and relevant. This comprehensive approach highlights how data management plays a crucial role in supporting effective data collection practices.&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965_rej1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;Which technique uses existing data and adds more data?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Lexical fail: overlap=0.242&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-03-23T21:06:15.016874&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The technique that uses existing data and adds more data is data augmentation. The passage clearly explains that it enhances current datasets by incorporating additional external information, making it a valuable step after data discovery. This approach helps improve model performance without needing entirely new data sources.&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965_rej2&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What role do individual techniques play in data acquisition?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Quote/answer mismatch (6% overlap)&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-03-23T21:06:15.016874&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The individual techniques serve distinct purposes in expanding or improving dataset availability. Data discovery helps locate existing datasets, while data augmentation enriches what&#92;&#92;u2019s already there, and data generation offers a way to create new data when external sources are limited. Together, they provide flexibility depending on the availability of resources and the needs of the project.&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965_rej3&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;34c7848d-f3e1-42c2-a1f6-c9b3102de965&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Hard&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How are these techniques related?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Quote/answer mismatch (5% overlap)&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-03-23T21:06:15.016874&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;These techniques are interconnected as they each address different facets of data a ...
