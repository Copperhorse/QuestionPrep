# %%
import marimo as mo

# %%
import sqlalchemy

DATABASE_URL = "sqlite:////home/copper/Desktop/Project/QuestionPrep/data/rag_staging.db"
engine = sqlalchemy.create_engine(DATABASE_URL)

# %%
_df = mo.sql(
    f"""
    Select * FROm files
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='vblA-0' random-id='6b6ff9aa-2c1a-96e2-8b78-cab3d366e86e'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;file_path&#92;&quot;:&#92;&quot;/home/copper/Documents/document_LLM_backbone_tutorial.pdf&#92;&quot;,&#92;&quot;file_name&#92;&quot;:&#92;&quot;document_LLM_backbone_tutorial.pdf&#92;&quot;,&#92;&quot;simhash&#92;&quot;:&#92;&quot;61ed79455f87d5d7&#92;&quot;,&#92;&quot;format&#92;&quot;:&#92;&quot;PDF 1.4&#92;&quot;,&#92;&quot;title&#92;&quot;:&#92;&quot;llm_backbone_tutorial_short.docx - Google Docs&#92;&quot;,&#92;&quot;author&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;creation_date&#92;&quot;:&#92;&quot;D:20260109144105+00&#x27;00&#x27;&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-19T03:38:06.264179&#92;&quot;,&#92;&quot;content_length&#92;&quot;:22303},{&#92;&quot;file_id&#92;&quot;:&#92;&quot;2c2f8ef0-bd12-4f01-9148-0730bdc0da87&#92;&quot;,&#92;&quot;file_path&#92;&quot;:&#92;&quot;/home/copper/Documents/1811.03402v2.pdf&#92;&quot;,&#92;&quot;file_name&#92;&quot;:&#92;&quot;1811.03402v2.pdf&#92;&quot;,&#92;&quot;simhash&#92;&quot;:&#92;&quot;6fc90de255c6d717&#92;&quot;,&#92;&quot;format&#92;&quot;:&#92;&quot;PDF 1.5&#92;&quot;,&#92;&quot;title&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;author&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;creation_date&#92;&quot;:&#92;&quot;D:20190813003526Z&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-21T07:42:28.844229&#92;&quot;,&#92;&quot;content_length&#92;&quot;:122903}]&quot;' data-total-rows='2' data-total-columns='10' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;file_id&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;file_path&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;file_name&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;simhash&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;format&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;title&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;author&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;creation_date&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;processed_at&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;content_length&quot;,[&quot;integer&quot;,&quot;i64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
_df = mo.sql(
    f"""
    SELECT
        *
    FROM
        chunks
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='bkHC-0' random-id='f755fcab-5912-cd8e-cc1a-e9d5cc4a2c5c'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;9ae0503a-7b1f-4471-a7fd-0dec634147e9&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:0,&#92;&quot;content&#92;&quot;:&#92;&quot;Explore mechanisms and hands-on implementation of RAG, tokenizers, and inference logics&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:17,&#92;&quot;section_header&#92;&quot;:&#92;&quot;Building a LLM backbone with a RAG framework from Scratch&#92;&quot;,&#92;&quot;parent_section&#92;&quot;:null,&#92;&quot;top_header&#92;&quot;:&#92;&quot;Building a LLM backbone with a RAG framework from Scratch&#92;&quot;,&#92;&quot;prev_chunk_id&#92;&quot;:null,&#92;&quot;next_chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;quality_score&#92;&quot;:70.0,&#92;&quot;should_use&#92;&quot;:1},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:1,&#92;&quot;content&#92;&quot;:&#92;&quot;A Large Language Model (LLM) transforms vast datasets into a mathematical foundation.&#92;&#92;n&#92;&#92;nWhile proprietary LLMs offer rapid deployment via APIs, they function like a black box with limited transparency.&#92;&#92;n&#92;&#92;nSo, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone. Specifically, we&#x27;ll implement a RAG (Retrieval-Augmented Generation) framework for document-grounded reasoning, focusing on:&#92;&#92;n&#92;&#92;n- Data Curation,&#92;&#92;n- Preprocessing, and&#92;&#92;n- Inference &amp;amp; Decoding Logic.&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:112,&#92;&quot;section_header&#92;&quot;:&#92;&quot;Introduction&#92;&quot;,&#92;&quot;parent_section&#92;&quot;:null,&#92;&quot;top_header&#92;&quot;:&#92;&quot;Introduction&#92;&quot;,&#92;&quot;prev_chunk_id&#92;&quot;:&#92;&quot;9ae0503a-7b1f-4471-a7fd-0dec634147e9&#92;&quot;,&#92;&quot;next_chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;quality_score&#92;&quot;:100.0,&#92;&quot;should_use&#92;&quot;:1},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:2,&#92;&quot;content&#92;&quot;:&#92;&quot;In this project, we&#x27;ll implement a RAG framework for reasoning tasks, using pre-trained weights to summarize information retrieved from unstructured web-crawled data and WARC archives.&#92;&#92;n&#92;&#92;n&lt;!-- image --&gt;&#92;&#92;n&#92;&#92;nFigure A. The system workflow (Created by   Kuriko IWAI  )&#92;&#92;n&#92;&#92;nThe workflow begins when a user submits a query and an HTML reference via the Streamlit interface.&#92;&#92;n&#92;&#92;nThe backend, powered by FastAPI , extracts and structures the raw text into a prompt for the model.&#92;&#92;n&#92;&#92;nThen, the system utilizes a custom BPE tokenizer (orange boxes) to process the user query and crawled data, feeding them into a uniquely configured GPT-based model (green box).&#92;&#92;n&#92;&#92;nThe model then performs an autoregressive process to generate a response by predicting subsequent tokens.&#92;&#92;n&#92;&#92;nFinally, the BPE tokenizer decodes these tokens into human-readable text for the user.&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:168,&#92;&quot;section_header&#92;&quot;:&#92;&quot;The System Architecture&#92;&quot;, ...

# %%
_df = mo.sql(
    f"""
    SELECT
        *
    FROM
        chunk_enrichments
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='lEQa-0' random-id='47447fb0-eadd-cc15-6014-c618e6c6c8cb'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;9ae0503a-7b1f-4471-a7fd-0dec634147e9&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;RAG&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;Tokenization&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;InferenceLogic&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;RAG system&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;implements&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;mechanisms&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;Tokenizer&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;converts&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;text into tokens&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;Inference engine&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;processes&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;RAG outputs&#92;&#92;&#92;&quot;}]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The discussion focuses on the mechanisms and practical implementation of RAG systems, tokenization processes, and inference logic.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-21T10:47:39.418969&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;LLM&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;RAG&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;Document Reasoning&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;Data Curation&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;Retrieval-Augmented Generation&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;uses&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;RAG framework&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;LLM&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;transforms&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;vast datasets&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;GPT-style model&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;built from scratch&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;custom implementation&#92;&#92;&#92;&quot;}]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;The project centers on developing a custom GPT-style model from scratch, emphasizing RAG-based document reasoning, data curation, and inference logic.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-21T10:53:12.191826&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;fe9331f3-48a0-465f-a73a-2ead8b81f143&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data acquisition&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data labeling&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;machine learning&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92 ...

# %%
_df = mo.sql(
    f"""
    SELECT * FROM chunk_questions
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='PKri-0' random-id='b35f5d6e-afba-3b11-79ef-698494d0a7af'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What does a RAG framework aim to achieve in document-grounded reasoning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;A RAG framework aims to achieve document-grounded reasoning by enhancing inference and decoding logic through retrieval-augmented processes.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;building a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Fact&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q2&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;Which process involves transforming datasets into a mathematical foundation for the model?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The process that involves transforming datasets into a mathematical foundation for the model is Data Curation.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;transforms vast datasets into a mathematical foundation&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Fact&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q3&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How does the RAG framework handle data curation in document-grounded reasoning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The RAG framework handles data curation by focusing on data curation, preprocessing, and inference &amp; decoding logic.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;We&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone.&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Mechanism&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q4&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How is the retrieval process integrated into the inference workflow within the RAG framework?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The retrieval process is integrated into the inference workflow by leveraging RAG to augment generation with relevant document context.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;So, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone.&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Mechanism&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q5&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What are the primary limitations of using a black box LLM without RAG for document-grounded reasoning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The primary limitations are the lack of transparency and the inability to ground reasoning in retrieved data.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;So, in this project, we&#x27;ll build a GPT-style model from scratch, movi ...

# %%
_df = mo.sql(
    f"""
    SELECT  q.question_text, q.answer_text,q.source_quote,c.content,c.chunk_id
    FROM chunk_questions q
    JOIN chunks c ON q.chunk_id = c.chunk_id
    WHERE c.should_use = 1
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='SFPL-0' random-id='521ff140-eb34-f064-d211-159088c4e678'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;question_text&#92;&quot;:&#92;&quot;What does a RAG framework aim to achieve in document-grounded reasoning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;A RAG framework aims to achieve document-grounded reasoning by enhancing inference and decoding logic through retrieval-augmented processes.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;building a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;A Large Language Model (LLM) transforms vast datasets into a mathematical foundation.&#92;&#92;n&#92;&#92;nWhile proprietary LLMs offer rapid deployment via APIs, they function like a black box with limited transparency.&#92;&#92;n&#92;&#92;nSo, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone. Specifically, we&#x27;ll implement a RAG (Retrieval-Augmented Generation) framework for document-grounded reasoning, focusing on:&#92;&#92;n&#92;&#92;n- Data Curation,&#92;&#92;n- Preprocessing, and&#92;&#92;n- Inference &amp;amp; Decoding Logic.&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;},{&#92;&quot;question_text&#92;&quot;:&#92;&quot;Which process involves transforming datasets into a mathematical foundation for the model?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The process that involves transforming datasets into a mathematical foundation for the model is Data Curation.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;transforms vast datasets into a mathematical foundation&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;A Large Language Model (LLM) transforms vast datasets into a mathematical foundation.&#92;&#92;n&#92;&#92;nWhile proprietary LLMs offer rapid deployment via APIs, they function like a black box with limited transparency.&#92;&#92;n&#92;&#92;nSo, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone. Specifically, we&#x27;ll implement a RAG (Retrieval-Augmented Generation) framework for document-grounded reasoning, focusing on:&#92;&#92;n&#92;&#92;n- Data Curation,&#92;&#92;n- Preprocessing, and&#92;&#92;n- Inference &amp;amp; Decoding Logic.&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;},{&#92;&quot;question_text&#92;&quot;:&#92;&quot;How does the RAG framework handle data curation in document-grounded reasoning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The RAG framework handles data curation by focusing on data curation, preprocessing, and inference &amp; decoding logic.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;We&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone.&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;A Large Language Model (LLM) transforms vast datasets into a mathematical foundation.&#92;&#92;n&#92;&#92;nWhile proprietary LLMs offer rapid deployment via APIs, they function like a black box with limited transparency.&#92;&#92;n&#92;&#92;nSo, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone. Specifically, we&#x27;ll implement a RAG (Retrieval-Augmented Generation) framework for document-grounded reasoning, focusing on:&#92;&#92;n&#92;&#92;n- Data Curation,&#92;&#92;n- Preprocessing, and&#92;&#92;n- Inference &amp;amp; Decoding Logic.&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;},{&#92;&quot;question_text&#92;&quot;:&#92;&quot;How is the retrieval process integrated into the inference workflow with ...

# %%
_df = mo.sql(
    f"""
    SELECT * FROM chunk_rejections
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='BYtC-0' random-id='348e195a-3b6a-74e4-56bb-e2f12b6ef334'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_rej1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What is the primary function of data curation in this context?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Invalid Pass 1&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-21T10:53:13.745740&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_rej2&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What role does preprocessing play in the inference and decoding logic of the RAG system?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Weak quote (74.7%)&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-21T10:53:13.745740&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374_rej1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How does the system structure raw text for the model input?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Why/How-question without causal/mechanism phrase&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-21T11:03:07.884870&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374_rej2&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Hard&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What trade-offs exist between using pre-trained weights and training a custom model for inference?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Semantic fail: cos=0.507&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-21T11:03:07.884870&#92;&quot;}]&quot;' data-total-rows='4' data-total-columns='7' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;rejection_id&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;chunk_id&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;level&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;question_text&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;reason&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;semantic_score&quot;,[&quot;unknown&quot;,&quot;null&quot;]],[&quot;rejected_at&quot;,[&quot;string&quot;,&quot;str&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>
