# %%
import marimo as mo

# %%
import sqlalchemy

DATABASE_URL = (
    "sqlite:////home/copper/Desktop/Project/QuestionPrep/data/rag_staging.db"
)
engine = sqlalchemy.create_engine(DATABASE_URL)

# %%
_df = mo.sql(
    f"""
    Select * FROm files
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='vblA-0' random-id='c34c3135-5c51-66e5-b5f3-0aac7e4a5047'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;file_path&#92;&quot;:&#92;&quot;/home/copper/Documents/document_LLM_backbone_tutorial.pdf&#92;&quot;,&#92;&quot;file_name&#92;&quot;:&#92;&quot;document_LLM_backbone_tutorial.pdf&#92;&quot;,&#92;&quot;simhash&#92;&quot;:&#92;&quot;61ed79455f87d5d7&#92;&quot;,&#92;&quot;format&#92;&quot;:&#92;&quot;PDF 1.4&#92;&quot;,&#92;&quot;title&#92;&quot;:&#92;&quot;llm_backbone_tutorial_short.docx - Google Docs&#92;&quot;,&#92;&quot;author&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;creation_date&#92;&quot;:&#92;&quot;D:20260109144105+00&#x27;00&#x27;&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-19T03:38:06.264179&#92;&quot;,&#92;&quot;content_length&#92;&quot;:22303},{&#92;&quot;file_id&#92;&quot;:&#92;&quot;2c2f8ef0-bd12-4f01-9148-0730bdc0da87&#92;&quot;,&#92;&quot;file_path&#92;&quot;:&#92;&quot;/home/copper/Documents/1811.03402v2.pdf&#92;&quot;,&#92;&quot;file_name&#92;&quot;:&#92;&quot;1811.03402v2.pdf&#92;&quot;,&#92;&quot;simhash&#92;&quot;:&#92;&quot;6fc90de255c6d717&#92;&quot;,&#92;&quot;format&#92;&quot;:&#92;&quot;PDF 1.5&#92;&quot;,&#92;&quot;title&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;author&#92;&quot;:&#92;&quot;&#92;&quot;,&#92;&quot;creation_date&#92;&quot;:&#92;&quot;D:20190813003526Z&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-21T07:42:28.844229&#92;&quot;,&#92;&quot;content_length&#92;&quot;:122903}]&quot;' data-total-rows='2' data-total-columns='10' data-max-columns='50' data-banner-text='&quot;&quot;' data-pagination='true' data-page-size='10' data-field-types='[[&quot;file_id&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;file_path&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;file_name&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;simhash&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;format&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;title&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;author&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;creation_date&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;processed_at&quot;,[&quot;string&quot;,&quot;str&quot;]],[&quot;content_length&quot;,[&quot;integer&quot;,&quot;i64&quot;]]]' data-show-filters='true' data-show-download='true' data-show-column-summaries='false' data-show-data-types='true' data-show-page-size-selector='false' data-show-column-explorer='true' data-show-chart-builder='true' data-row-headers='[]' data-has-stable-row-id='false' data-lazy='false' data-preload='false'></marimo-table></marimo-ui-element>

# %%
_df = mo.sql(
    f"""
    SELECT
        *
    FROM
        chunks
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='bkHC-0' random-id='e9e6a8a0-9092-bd49-2178-183c2d3cfc12'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;9ae0503a-7b1f-4471-a7fd-0dec634147e9&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:0,&#92;&quot;content&#92;&quot;:&#92;&quot;Explore mechanisms and hands-on implementation of RAG, tokenizers, and inference logics&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:17,&#92;&quot;section_header&#92;&quot;:&#92;&quot;Building a LLM backbone with a RAG framework from Scratch&#92;&quot;,&#92;&quot;parent_section&#92;&quot;:null,&#92;&quot;top_header&#92;&quot;:&#92;&quot;Building a LLM backbone with a RAG framework from Scratch&#92;&quot;,&#92;&quot;prev_chunk_id&#92;&quot;:null,&#92;&quot;next_chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;quality_score&#92;&quot;:70.0,&#92;&quot;should_use&#92;&quot;:1},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:1,&#92;&quot;content&#92;&quot;:&#92;&quot;A Large Language Model (LLM) transforms vast datasets into a mathematical foundation.&#92;&#92;n&#92;&#92;nWhile proprietary LLMs offer rapid deployment via APIs, they function like a black box with limited transparency.&#92;&#92;n&#92;&#92;nSo, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone. Specifically, we&#x27;ll implement a RAG (Retrieval-Augmented Generation) framework for document-grounded reasoning, focusing on:&#92;&#92;n&#92;&#92;n- Data Curation,&#92;&#92;n- Preprocessing, and&#92;&#92;n- Inference &amp;amp; Decoding Logic.&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:112,&#92;&quot;section_header&#92;&quot;:&#92;&quot;Introduction&#92;&quot;,&#92;&quot;parent_section&#92;&quot;:null,&#92;&quot;top_header&#92;&quot;:&#92;&quot;Introduction&#92;&quot;,&#92;&quot;prev_chunk_id&#92;&quot;:&#92;&quot;9ae0503a-7b1f-4471-a7fd-0dec634147e9&#92;&quot;,&#92;&quot;next_chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;quality_score&#92;&quot;:100.0,&#92;&quot;should_use&#92;&quot;:1},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;file_id&#92;&quot;:&#92;&quot;6d1dc034-2a37-4157-b297-449b5eb29b24&#92;&quot;,&#92;&quot;chunk_index&#92;&quot;:2,&#92;&quot;content&#92;&quot;:&#92;&quot;In this project, we&#x27;ll implement a RAG framework for reasoning tasks, using pre-trained weights to summarize information retrieved from unstructured web-crawled data and WARC archives.&#92;&#92;n&#92;&#92;n&lt;!-- image --&gt;&#92;&#92;n&#92;&#92;nFigure A. The system workflow (Created by   Kuriko IWAI  )&#92;&#92;n&#92;&#92;nThe workflow begins when a user submits a query and an HTML reference via the Streamlit interface.&#92;&#92;n&#92;&#92;nThe backend, powered by FastAPI , extracts and structures the raw text into a prompt for the model.&#92;&#92;n&#92;&#92;nThen, the system utilizes a custom BPE tokenizer (orange boxes) to process the user query and crawled data, feeding them into a uniquely configured GPT-based model (green box).&#92;&#92;n&#92;&#92;nThe model then performs an autoregressive process to generate a response by predicting subsequent tokens.&#92;&#92;n&#92;&#92;nFinally, the BPE tokenizer decodes these tokens into human-readable text for the user.&#92;&quot;,&#92;&quot;content_type&#92;&quot;:&#92;&quot;prose&#92;&quot;,&#92;&quot;estimated_tokens&#92;&quot;:168,&#92;&quot;section_header&#92;&quot;:&#92;&quot;The System Architecture&#92;&quot;, ...

# %%
_df = mo.sql(
    f"""
    SELECT
        *
    FROM
        chunk_enrichments
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='lEQa-0' random-id='f921f1e4-d02e-4f86-dd18-78e0bec7963c'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;data_curation&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;entity&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;is_part_of&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;entity&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;entity&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;underwent&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data_curation&#92;&#92;&#92;&quot;}]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;the text discusses building a gpt-style model from scratch focusing on data curation, preprocessing, and inference logic.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-24T09:37:03.133027&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;fe9331f3-48a0-465f-a73a-2ead8b81f143&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;data_collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data_acquisition&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data_labeling&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;consists_of&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: [&#92;&#92;&#92;&quot;data acquisition&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;data labeling&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;model improvement&#92;&#92;&#92;&quot;]}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data management&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;plays_role_in&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;machine learning&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;relies_on&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;data collection&#92;&#92;&#92;&quot;}]&#92;&quot;,&#92;&quot;summary&#92;&quot;:&#92;&quot;the text discusses data collection challenges and perspectives from a data management viewpoint within machine learning research.&#92;&quot;,&#92;&quot;processed_at&#92;&quot;:&#92;&quot;2026-02-24T09:37:18.643256&#92;&quot;},{&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;6e2c3b41-1acd-479a-a1ba-7120c4115374&#92;&quot;,&#92;&quot;tags&#92;&quot;:&#92;&quot;[&#92;&#92;&#92;&quot;noun_tag1&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;noun_tag2&#92;&#92;&#92;&quot;]&#92;&quot;,&#92;&quot;triplets&#92;&quot;:&#92;&quot;[{&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;system workflow&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;begins_with&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;user query&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subject&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;backend&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;predicate&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;is_powered_by&#92;&#92;&#92;&quot;, &#92;&#92;&#92;&quot;object&#92;&#92;&#92;&quot;: &#92;&#92;&#92;&quot;fastapi&#92;&#92;&#92;&quot;}, {&#92;&#92;&#92;&quot;subj ...

# %%
_df = mo.sql(
    f"""
    SELECT * FROM chunk_questions
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='PKri-0' random-id='68a9a864-724c-bc14-bfdf-c5ab98d2cda6'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What does the LLM transform into a mathematical foundation?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The LLM transforms vast datasets into a mathematical foundation.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;A Large Language Model (LLM) transforms vast datasets into a mathematical foundation.&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Fact&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q2&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What is the primary function of the RAG framework in this project?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The primary function of the RAG framework in this project is to enable document-grounded reasoning by integrating retrieval-based augmentation with generation.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone.&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Fact&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q3&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How does the RAG framework improve the transparency of the model&#x27;s reasoning process?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The RAG framework enhances transparency by grounding reasoning in retrieved data, allowing the model&#x27;s decision-making to be traceable to specific sources.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;building a GPT-style model from scratch, moving beyond third-party integrations&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Mechanism&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q4&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How does the proposed RAG framework address the transparency limitations of third-party LLMs?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The proposed RAG framework addresses the transparency limitations by building a model from scratch, which allows for deeper understanding of the underlying processes, unlike third-party LLMs that operate as black boxes.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;So, in this project, we&#x27;ll build a GPT-style model from scratch, moving beyond third-party integrations to understand the backbone.&#92;&quot;,&#92;&quot;difficulty&#92;&quot;:&#92;&quot;Hard&#92;&quot;,&#92;&quot;question_type&#92;&quot;:&#92;&quot;Critical&#92;&quot;},{&#92;&quot;question_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_q5&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What specific challenges arise when implementing data curation and preprocessing for document-grounded reasoning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The specific challenges arise when implementing data curation and preprocessing for document-grounded reasoning due to the need for careful handling of proprie ...

# %%
_df = mo.sql(
    f"""
    SELECT 
        q.question_text, 
        q.answer_text, 
        q.source_quote,
        c.content,
        c.chunk_id
    FROM chunk_questions q
    JOIN chunks c 
        ON q.chunk_id = c.chunk_id
    JOIN chunk_enrichments e 
        ON e.chunk_id = c.chunk_id
    WHERE c.should_use = 1 
    ORDER by e.processed_at DESC
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='SFPL-0' random-id='a732325e-4c03-9a9d-3264-cc620569be9a'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;question_text&#92;&quot;:&#92;&quot;What is the primary reason data collection has become a critical issue in machine learning?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The primary reason data collection has become a critical issue in machine learning is that as machine learning is becoming more widely used, new applications are emerging that do not necessarily have enough labeled data.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;Data collection is a major bottleneck in machine learning and an active research topic in multiple communities.&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;A Big Data - AI Integration Perspective&#92;&#92;n&#92;&#92;nYuji Roh, Geon Heo, Steven Euijong Whang, Senior Member, IEEE&#92;&#92;n&#92;&#92;nAbstract -Data collection is a major bottleneck in machine learning and an active research topic in multiple communities. There are largely two reasons data collection has recently become a critical issue. First, as machine learning is becoming more widely-used, we are seeing new applications that do not necessarily have enough labeled data. Second, unlike traditional machine learning, deep learning techniques automatically generate features, which saves feature engineering costs, but in return may require larger amounts of labeled data. Interestingly, recent research in data collection comes not only from the machine learning, natural language, and computer vision communities, but also from the data management community due to the importance of handling large amounts of data. In this survey, we perform a comprehensive study of data collection from a data management point of view. Data collection largely consists of data acquisition, data labeling, and improvement of existing data or models. We provide a research landscape of these operations, provide guidelines on which technique to use when, and identify interesting research challenges. The integration of machine learning and data management for data collection is part of a larger trend of Big data and Artificial Intelligence (AI) integration and opens many opportunities for new research.&#92;&#92;n&#92;&#92;nIndex Terms -data collection, data acquisition, data labeling, machine learning&#92;&#92;n&#92;&#92;nF&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;fe9331f3-48a0-465f-a73a-2ead8b81f143&#92;&quot;},{&#92;&quot;question_text&#92;&quot;:&#92;&quot;Which communities are contributing to the research on data collection?&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The research on data collection is coming from machine learning, natural language, computer vision, and data management communities.&#92;&quot;,&#92;&quot;source_quote&#92;&quot;:&#92;&quot;Recent research in data collection comes not only from the machine learning, natural language, and computer vision communities, but also from the data management community due to the importance of handling large amounts of data.&#92;&quot;,&#92;&quot;content&#92;&quot;:&#92;&quot;A Big Data - AI Integration Perspective&#92;&#92;n&#92;&#92;nYuji Roh, Geon Heo, Steven Euijong Whang, Senior Member, IEEE&#92;&#92;n&#92;&#92;nAbstract -Data collection is a major bottleneck in machine learning and an active research topic in multiple communities. There are largely two reasons data collection has recently become a critical issue. First, as machine learning is becoming more widely-used, we are seeing new applications that do not necessarily have enough labeled data. Second, unlike traditional machine learning, deep learning techniques automatically generate features, which saves feature engineering costs, but in return may require larger amounts of labeled data. Interestingly, recent research in data collection comes not only from the machine learning, natural language, and computer vision comm ...

# %%
_df = mo.sql(
    f"""
    SELECT * FROM chunk_rejections
    """,
    engine=engine
)
# Out:
# <marimo-ui-element object-id='BYtC-0' random-id='b107651e-f80f-9c8e-de5b-28ddbc7b39fb'><marimo-table data-initial-value='[]' data-label='null' data-data='&quot;[{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_rej1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Easy&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;Which concept refers to the process of retrieving relevant documents before generating responses?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Lexical fail: overlap=0.231&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-24T09:41:45.023156&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The concept that refers to the process of retrieving relevant documents before generating responses is Retrieval-Augmented Generation.&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_rej2&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;What role does data curation play in the retrieval-augmented generation approach described?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Invalid Pass 1&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-24T09:41:45.023156&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_rej3&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;Why is preprocessing considered a critical step in the inference and decoding logic?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Invalid Pass 1&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-24T09:41:45.023156&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4_rej4&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;b396cf9b-ebab-4cfa-8fc1-75aa62dfcfe4&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Hard&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;How does the inference and decoding logic differ between a black-box LLM and a custom RAG system built from scratch?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Why/How-question without causal/mechanism phrase&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-24T09:41:45.023156&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The inference and decoding logic differs significantly, as the custom RAG system is designed for document-grounded reasoning while the black-box LLM operates with limited transparency.&#92;&quot;},{&#92;&quot;rejection_id&#92;&quot;:&#92;&quot;fe9331f3-48a0-465f-a73a-2ead8b81f143_rej1&#92;&quot;,&#92;&quot;chunk_id&#92;&quot;:&#92;&quot;fe9331f3-48a0-465f-a73a-2ead8b81f143&#92;&quot;,&#92;&quot;level&#92;&quot;:&#92;&quot;Medium&#92;&quot;,&#92;&quot;question_text&#92;&quot;:&#92;&quot;Why might feature engineering costs decrease with deep learning techniques?&#92;&quot;,&#92;&quot;reason&#92;&quot;:&#92;&quot;Why/How-question without causal/mechanism phrase&#92;&quot;,&#92;&quot;semantic_score&#92;&quot;:null,&#92;&quot;rejected_at&#92;&quot;:&#92;&quot;2026-02-24T09:44:35.575984&#92;&quot;,&#92;&quot;answer_text&#92;&quot;:&#92;&quot;The integration of machine learning with data management for data collection is part of a larger trend of Big data and Artificial Intelligence integration, which opens many opportunities for new research.&#92;&quot;}]&q ...
